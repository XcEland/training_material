# %%
# !pip install pandas openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]━━ 1/2 [openpyxl]
# ...

# %%
import pandas as pd

# %%
from pathlib import Path

print("Current working directory:")
print(Path.cwd())

print("\nExcel files found in this project:")
for file in Path(".").rglob("*.xlsx"):
    print(file)
# Out:
# Current working directory:
# /home/xceland/Desktop/Trainingcred Institute/Module 4/labs/python-data-manipulation-database-connectivity
#
# Excel files found in this project:
# data/WEOApr2026all.xlsx

# %%
# df = pd.read_excel('data/WEOApr2026all.xlsx', sheet_name = 'Countries')
# df = pd.read_excel('data/WEOApr2026all.xlsx', sheet_name = 1)
# df.head()
df = pd.read_excel('data/WEOApr2026all.xlsx', sheet_name = None)
sheet1_df = df['Countries']
sheet1_df.head()
# Out:
#               DATASET      SERIES_CODE COUNTRY.ID                   COUNTRY  \
# 0  IMF.RES:WEO(9.0.0)     AND.NGDP_R.A        AND  Andorra, Principality of
# 1  IMF.RES:WEO(9.0.0)  AND.NGDP_RPCH.A        AND  Andorra, Principality of
# 2  IMF.RES:WEO(9.0.0)       AND.NGDP.A        AND  Andorra, Principality of
# 3  IMF.RES:WEO(9.0.0)      AND.NGDPD.A        AND  Andorra, Principality of
# 4  IMF.RES:WEO(9.0.0)     AND.PPPGDP.A        AND  Andorra, Principality of
#
#   INDICATOR.ID                                          INDICATOR  \
# 0       NGDP_R  Gross domestic product (GDP), Constant prices,...
# 1    NGDP_RPCH  Gross domestic product (GDP), Constant prices,...
# 2         NGDP  Gross domestic product (GDP), Current prices, ...
# 3        NGDPD  Gross domestic product (GDP), Current prices, ...
# 4       PPPGDP  Gross domestic product (GDP), Current prices, ...
#
#                                INDICATOR.Description FREQUENCY     SCALE  \
# ...

# %%
df = pd.read_excel('data/WEOApr2026all.xlsx', sheet_name = 1,usecols='A:C', skiprows=2, skipfooter=3)
df.head()
# Out:
#    IMF.RES:WEO(9.0.0) AND.NGDP_RPCH.A  AND
# 0  IMF.RES:WEO(9.0.0)      AND.NGDP.A  AND
# 1  IMF.RES:WEO(9.0.0)     AND.NGDPD.A  AND
# 2  IMF.RES:WEO(9.0.0)    AND.PPPGDP.A  AND
# 3  IMF.RES:WEO(9.0.0)    AND.NGDP_D.A  AND
# 4  IMF.RES:WEO(9.0.0)   AND.NGDPRPC.A  AND

# %%
import pandas as pd

# Load data while skipping the last 3 rows (adjust number if needed)
df = pd.read_excel(
    'data/WEOApr2026all.xlsx', 
    sheet_name=1, 
    usecols=['DATASET', 'SERIES_CODE'],
    skipfooter=3
)

# View the last few rows to confirm metadata is gone
print(df.tail())
# Out:
#                  DATASET         SERIES_CODE
# 8660  IMF.RES:WEO(9.0.0)  ZWE.GGXONLB_NGDP.A
# 8661  IMF.RES:WEO(9.0.0)        ZWE.GGXWDN.A
# 8662  IMF.RES:WEO(9.0.0)   ZWE.GGXWDN_NGDP.A
# 8663  IMF.RES:WEO(9.0.0)        ZWE.GGXWDG.A
# 8664  IMF.RES:WEO(9.0.0)   ZWE.GGXWDG_NGDP.A

# %%
df = pd.read_excel('data/WEOApr2026all.xlsx', sheet_name = 1,usecols=['DATASET','SERIES_CODE'])
df.head()
# Out:
#               DATASET      SERIES_CODE
# 0  IMF.RES:WEO(9.0.0)     AND.NGDP_R.A
# 1  IMF.RES:WEO(9.0.0)  AND.NGDP_RPCH.A
# 2  IMF.RES:WEO(9.0.0)       AND.NGDP.A
# 3  IMF.RES:WEO(9.0.0)      AND.NGDPD.A
# 4  IMF.RES:WEO(9.0.0)     AND.PPPGDP.A

# %%
df['Countries'].head()
# Out:
#               DATASET      SERIES_CODE COUNTRY.ID                   COUNTRY  \
# 0  IMF.RES:WEO(9.0.0)     AND.NGDP_R.A        AND  Andorra, Principality of
# 1  IMF.RES:WEO(9.0.0)  AND.NGDP_RPCH.A        AND  Andorra, Principality of
# 2  IMF.RES:WEO(9.0.0)       AND.NGDP.A        AND  Andorra, Principality of
# 3  IMF.RES:WEO(9.0.0)      AND.NGDPD.A        AND  Andorra, Principality of
# 4  IMF.RES:WEO(9.0.0)     AND.PPPGDP.A        AND  Andorra, Principality of
#
#   INDICATOR.ID                                          INDICATOR  \
# 0       NGDP_R  Gross domestic product (GDP), Constant prices,...
# 1    NGDP_RPCH  Gross domestic product (GDP), Constant prices,...
# 2         NGDP  Gross domestic product (GDP), Current prices, ...
# 3        NGDPD  Gross domestic product (GDP), Current prices, ...
# 4       PPPGDP  Gross domestic product (GDP), Current prices, ...
#
#                                INDICATOR.Description FREQUENCY     SCALE  \
# ...

# %%
for sheet_name, df2 in df.items():
    print(f"--- Sheet Name: {sheet_name} ---")
    print(df1.head(2))
    print("\n")
# Out:
# --- Sheet Name: April 2026 WEO ---
#    Unnamed: 0 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN        NaN         NaN         NaN         NaN         NaN
# 1         NaN        NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7 Unnamed: 8
# 0         NaN         NaN        NaT
# 1         NaN         NaN 2026-04-14
#
#
# --- Sheet Name: Countries ---
#               DATASET      SERIES_CODE COUNTRY.ID                   COUNTRY  \
# 0  IMF.RES:WEO(9.0.0)     AND.NGDP_R.A        AND  Andorra, Principality of
# 1  IMF.RES:WEO(9.0.0)  AND.NGDP_RPCH.A        AND  Andorra, Principality of
#
#   INDICATOR.ID                                          INDICATOR  \
# 0       NGDP_R  Gross domestic product (GDP), Constant prices,...
# 1    NGDP_RPCH  Gross domestic product (GDP), Constant prices,...
#
#                                INDICATOR.Description FREQUENCY     SCALE  \
# ...

# %%
print(df.keys())
# Out:
# dict_keys(['April 2026 WEO', 'Countries', 'Country Groups', 'Commodity Prices', 'Country Group Composition'])

# %%
combined_df = pd.concat(df.values(), ignore_index=True)
combined_df.head()
# Out:
#    Unnamed: 0                       Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0         NaN                              NaN         NaN         NaN
# 1         NaN                              NaN         NaN         NaN
# 2         NaN                              NaN         NaN         NaN
# 3         NaN      International Monetary Fund         NaN         NaN
# 4         NaN  World Economic Outlook Database         NaN         NaN
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7 Unnamed: 8 DATASET  ...  \
# 0         NaN         NaN         NaN         NaN        NaT     NaN  ...
# 1         NaN         NaN         NaN         NaN 2026-04-14     NaN  ...
# 2         NaN         NaN         NaN         NaN        NaT     NaN  ...
# 3         NaN         NaN         NaN         NaN        NaT     NaN  ...
# 4         NaN         NaN         NaN         NaN        NaT     NaN  ...
#
#   2029 2030 2031 METHODOLOGY groupcode groupname groupcode_previous  \
# ...

# %%
df = pd.read_json('data.json')
print(df.to_string)

# %%
df.tail(10)
# Out:
#                  DATASET         SERIES_CODE
# 8655  IMF.RES:WEO(9.0.0)        ZWE.GGXCNL.A
# 8656  IMF.RES:WEO(9.0.0)   ZWE.GGXCNL_NGDP.A
# 8657  IMF.RES:WEO(9.0.0)          ZWE.GGSB.A
# 8658  IMF.RES:WEO(9.0.0)    ZWE.GGSB_NPGDP.A
# 8659  IMF.RES:WEO(9.0.0)       ZWE.GGXONLB.A
# 8660  IMF.RES:WEO(9.0.0)  ZWE.GGXONLB_NGDP.A
# 8661  IMF.RES:WEO(9.0.0)        ZWE.GGXWDN.A
# 8662  IMF.RES:WEO(9.0.0)   ZWE.GGXWDN_NGDP.A
# 8663  IMF.RES:WEO(9.0.0)        ZWE.GGXWDG.A
# 8664  IMF.RES:WEO(9.0.0)   ZWE.GGXWDG_NGDP.A

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8665 entries, 0 to 8664
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATASET      8665 non-null   str
#  1   SERIES_CODE  8665 non-null   str
# dtypes: str(2)
# memory usage: 135.5 KB
